# %% [markdown]
# # Evaluation of the `HaGraD`-Optimizer with Mnist-Dataset
# ---

# %% [markdown]
# ## Imports and Data-Preparation

# %%
## Tensorflow related
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers

## General
import numpy as np
import matplotlib.pyplot as plt

## Hagrad custom optimizer
from hagrad import Hagrad
from hagrad import KineticEnergyGradients

# %%
## Fetch Mnist-Dataset
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
assert X_train.shape == (60000, 28, 28)
assert X_test.shape  == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape  == (10000,)

# %%
## Class number sanity check
num_classes = 10
assert set(np.unique(y_train)) == set(np.arange(num_classes))

## Normalizing and expanding dimensions for ConvLayers
def normalize_img_data(X: np.ndarray) -> np.ndarray:
    X = X.astype(np.float32) / 255.
    X = np.expand_dims(X, -1)
    return X

X_train = normalize_img_data(X_train)
X_test  = normalize_img_data(X_test)

## convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test  = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ---

# %% [markdown]
# ## Defining the Model

# %%
## Using a standard Dense-Model here - sufficient for mnist.
def fully_connected_NN(
    input_shape: tuple,
    num_classes: int,
    optimizer: keras.optimizers.Optimizer,
    print_summary: bool=False) -> keras.Model:

    ## Defining the Model with Sequential API
    model = keras.Sequential([
        layers.Flatten(input_shape=input_shape),
        layers.Dense(128),
        layers.Dense(128),
        layers.Dense(128),
        layers.Dense(num_classes, activation="softmax")
    ])
    
    ## Compiling the Model using the given Optimizer
    model.compile(
        loss=keras.losses.CategoricalCrossentropy(), 
        optimizer=optimizer, 
        metrics=["accuracy"])

    ## Optional: Print Model summary
    if print_summary: print(model.summary())

    return model

# %% [markdown]
# ---

# %% [markdown]
# ## Train the Network using different Optimizers

# %%
## Settings
batch_size  = 128
epochs      = 50
input_shape = X_train.shape[1:]

# %%
## Wrappers
def model_optimizer(optimizer):
    model = fully_connected_NN(
        input_shape=input_shape, 
        num_classes=num_classes, 
        optimizer=optimizer, 
        print_summary=False)
    return model

def model_fit(model, verbose=2):
    fit = model.fit(
        X_train, y_train, 
        batch_size=batch_size, 
        epochs=epochs, 
        validation_data=(X_train, y_train), 
        verbose=verbose)
    return fit

# %% [markdown]
# #### Adam

# %%
keras.backend.clear_session()
model_adam = model_optimizer(keras.optimizers.Adam())
fit_adam = model_fit(model_adam)
# Out:
# Epoch 1/50
# 469/469 - 3s - loss: 0.3823 - accuracy: 0.8891 - val_loss: 0.2938 - val_accuracy: 0.9162
# Epoch 2/50
# 469/469 - 2s - loss: 0.3070 - accuracy: 0.9124 - val_loss: 0.3004 - val_accuracy: 0.9157
# Epoch 3/50
# 469/469 - 2s - loss: 0.2994 - accuracy: 0.9152 - val_loss: 0.2675 - val_accuracy: 0.9247
# Epoch 4/50
# 469/469 - 2s - loss: 0.2906 - accuracy: 0.9180 - val_loss: 0.2761 - val_accuracy: 0.9215
# Epoch 5/50
# 469/469 - 2s - loss: 0.2838 - accuracy: 0.9202 - val_loss: 0.2635 - val_accuracy: 0.9255
# Epoch 6/50
# 469/469 - 2s - loss: 0.2854 - accuracy: 0.9197 - val_loss: 0.2574 - val_accuracy: 0.9279
# Epoch 7/50
# 469/469 - 2s - loss: 0.2801 - accuracy: 0.9209 - val_loss: 0.2626 - val_accuracy: 0.9261
# Epoch 8/50
# 469/469 - 2s - loss: 0.2774 - accuracy: 0.9215 - val_loss: 0.2667 - val_accuracy: 0.9238
# Epoch 9/50
# 469/469 - 2s - loss: 0.2770 - accuracy: 0.9218 - val_loss: 0.2557 - val_accuracy: 0.9266
# Epoch 10/50
# 469/469 - 2s - loss: 0.2734 - accuracy: 0.9228 - val_loss: 0.2555 - val_accuracy: 0.9274
# Epoch 11/50
# 469/469 - 2s - loss: 0.2725 - accuracy: 0.9241 - val_loss: 0.2592 - val_accuracy: 0.9271
# Epoch 12/50
# 469/469 - 2s - loss: 0.2702 - accuracy: 0.9244 - val_loss: 0.2564 - val_accuracy: 0.9282
# Epoch 13/50
# 469/469 - 2s - loss: 0.2688 - accuracy: 0.9241 - val_loss: 0.2544 - val_accuracy: 0.9276
# Epoch 14/50
# 469/469 - 2s - loss: 0.2668 - accuracy: 0.9251 - val_loss: 0.2507 - val_accuracy: 0.9294
# Epoch 15/50
# 469/469 - 2s - loss: 0.2667 - accuracy: 0.9247 - val_loss: 0.2607 - val_accuracy: 0.9245
# Epoch 16/50
# 469/469 - 2s - loss: 0.2626 - accuracy: 0.9269 - val_loss: 0.2518 - val_accuracy: 0.9264
# Epoch 17/50
# 469/469 - 2s - loss: 0.2636 - accuracy: 0.9258 - val_loss: 0.2494 - val_accuracy: 0.9289
# Epoch 18/50
# 469/469 - 2s - loss: 0.2618 - accuracy: 0.9262 - val_loss: 0.2538 - val_accuracy: 0.9288
# Epoch 19/50
# 469/469 - 2s - loss: 0.2612 - accuracy: 0.9262 - val_loss: 0.2567 - val_accuracy: 0.9293
# Epoch 20/50
# 469/469 - 2s - loss: 0.2590 - accuracy: 0.9272 - val_loss: 0.2448 - val_accuracy: 0.9300
# Epoch 21/50
# 469/469 - 2s - loss: 0.2594 - accuracy: 0.9270 - val_loss: 0.2466 - val_accuracy: 0.9304
# Epoch 22/50
# 469/469 - 2s - loss: 0.2578 - accuracy: 0.9281 - val_loss: 0.2431 - val_accuracy: 0.9310
# Epoch 23/50
# 469/469 - 2s - loss: 0.2563 - accuracy: 0.9276 - val_loss: 0.2420 - val_accuracy: 0.9340
# Epoch 24/50
# 469/469 - 2s - loss: 0.2559 - accuracy: 0.9284 - val_loss: 0.2525 - val_accuracy: 0.9287
# Epoch 25/50
# 469/469 - 2s - loss: 0.2547 - accuracy: 0.9276 - val_loss: 0.2574 - val_accuracy: 0.9249
# Epoch 26/50
# 469/469 - 2s - loss: 0.2554 - accuracy: 0.9274 - val_loss: 0.2381 - val_accuracy: 0.9336
# Epoch 27/50
# 469/469 - 2s - loss: 0.2550 - accuracy: 0.9283 - val_loss: 0.2405 - val_accuracy: 0.9325
# Epoch 28/50
# 469/469 - 2s - loss: 0.2530 - accuracy: 0.9282 - val_loss: 0.2387 - val_accuracy: 0.9320
# Epoch 29/50
# 469/469 - 2s - loss: 0.2516 - accuracy: 0.9296 - val_loss: 0.2382 - val_accuracy: 0.9321
# Epoch 30/50
# 469/469 - 2s - loss: 0.2522 - accuracy: 0.9284 - val_loss: 0.2372 - val_accuracy: 0.9346
# Epoch 31/50
# 469/469 - 2s - loss: 0.2508 - accuracy: 0.9295 - val_loss: 0.2470 - val_accuracy: 0.9301
# Epoch 32/50
# 469/469 - 2s - loss: 0.2513 - accuracy: 0.9298 - val_loss: 0.2371 - val_accuracy: 0.9330
# Epoch 33/50
# 469/469 - 2s - loss: 0.2488 - accuracy: 0.9288 - val_loss: 0.2443 - val_accuracy: 0.9296
# Epoch 34/50
# 469/469 - 2s - loss: 0.2503 - accuracy: 0.9300 - val_loss: 0.2457 - val_accuracy: 0.9287
# Epoch 35/50
# 469/469 - 2s - loss: 0.2494 - accuracy: 0.9292 - val_loss: 0.2399 - val_accuracy: 0.9323
# Epoch 36/50
# 469/469 - 2s - loss: 0.2483 - accuracy: 0.9301 - val_loss: 0.2423 - val_accuracy: 0.9320
# Epoch 37/50
# 469/469 - 2s - loss: 0.2491 - accuracy: 0.9297 - val_loss: 0.2334 - val_accuracy: 0.9348
# Epoch 38/50
# 469/469 - 2s - loss: 0.2472 - accuracy: 0.9297 - val_loss: 0.2388 - val_accuracy: 0.9330
# Epoch 39/50
# 469/469 - 2s - loss: 0.2470 - accuracy: 0.9309 - val_loss: 0.2395 - val_accuracy: 0.9326
# Epoch 40/50
# 469/469 - 2s - loss: 0.2498 - accuracy: 0.9293 - val_loss: 0.2391 - val_accuracy: 0.9336
# Epoch 41/50
# 469/469 - 2s - loss: 0.2472 - accuracy: 0.9303 - val_loss: 0.2344 - val_accuracy: 0.9334
# Epoch 42/50
# 469/469 - 2s - loss: 0.2452 - accuracy: 0.9302 - val_loss: 0.2424 - val_accuracy: 0.9319
# Epoch 43/50
# 469/469 - 2s - loss: 0.2457 - accuracy: 0.9309 - val_loss: 0.2374 - val_accuracy: 0.9341
# Epoch 44/50
# 469/469 - 2s - loss: 0.2453 - accuracy: 0.9300 - val_loss: 0.2314 - val_accuracy: 0.9354
# Epoch 45/50
# 469/469 - 2s - loss: 0.2439 - accuracy: 0.9313 - val_loss: 0.2328 - val_accuracy: 0.9348
# Epoch 46/50
# 469/469 - 2s - loss: 0.2449 - accuracy: 0.9316 - val_loss: 0.2388 - val_accuracy: 0.9322
# Epoch 47/50
# 469/469 - 2s - loss: 0.2450 - accuracy: 0.9307 - val_loss: 0.2433 - val_accuracy: 0.9289
# Epoch 48/50
# 469/469 - 2s - loss: 0.2429 - accuracy: 0.9311 - val_loss: 0.2367 - val_accuracy: 0.9342
# Epoch 49/50
# 469/469 - 2s - loss: 0.2427 - accuracy: 0.9316 - val_loss: 0.2360 - val_accuracy: 0.9329
# Epoch 50/50
# 469/469 - 2s - loss: 0.2436 - accuracy: 0.9314 - val_loss: 0.2368 - val_accuracy: 0.9320

# %% [markdown]
# ### SGD

# %%
keras.backend.clear_session()
model_sgd = model_optimizer(keras.optimizers.SGD())
fit_sgd = model_fit(model_sgd)
# Out:
# Epoch 1/50
# 469/469 - 3s - loss: 0.7706 - accuracy: 0.7883 - val_loss: 0.4451 - val_accuracy: 0.8759
# Epoch 2/50
# 469/469 - 2s - loss: 0.3999 - accuracy: 0.8870 - val_loss: 0.3675 - val_accuracy: 0.8960
# Epoch 3/50
# 469/469 - 2s - loss: 0.3533 - accuracy: 0.8990 - val_loss: 0.3392 - val_accuracy: 0.9036
# Epoch 4/50
# 469/469 - 2s - loss: 0.3322 - accuracy: 0.9052 - val_loss: 0.3217 - val_accuracy: 0.9086
# Epoch 5/50
# 469/469 - 2s - loss: 0.3191 - accuracy: 0.9094 - val_loss: 0.3113 - val_accuracy: 0.9115
# Epoch 6/50
# 469/469 - 2s - loss: 0.3103 - accuracy: 0.9116 - val_loss: 0.3046 - val_accuracy: 0.9135
# Epoch 7/50
# 469/469 - 2s - loss: 0.3034 - accuracy: 0.9144 - val_loss: 0.2996 - val_accuracy: 0.9153
# Epoch 8/50
# 469/469 - 2s - loss: 0.2983 - accuracy: 0.9156 - val_loss: 0.2946 - val_accuracy: 0.9170
# Epoch 9/50
# 469/469 - 2s - loss: 0.2941 - accuracy: 0.9171 - val_loss: 0.2896 - val_accuracy: 0.9191
# Epoch 10/50
# 469/469 - 2s - loss: 0.2904 - accuracy: 0.9183 - val_loss: 0.2855 - val_accuracy: 0.9198
# Epoch 11/50
# 469/469 - 2s - loss: 0.2872 - accuracy: 0.9189 - val_loss: 0.2845 - val_accuracy: 0.9193
# Epoch 12/50
# 469/469 - 2s - loss: 0.2842 - accuracy: 0.9196 - val_loss: 0.2807 - val_accuracy: 0.9210
# Epoch 13/50
# 469/469 - 2s - loss: 0.2819 - accuracy: 0.9210 - val_loss: 0.2779 - val_accuracy: 0.9225
# Epoch 14/50
# 469/469 - 2s - loss: 0.2799 - accuracy: 0.9217 - val_loss: 0.2749 - val_accuracy: 0.9232
# Epoch 15/50
# 469/469 - 2s - loss: 0.2778 - accuracy: 0.9222 - val_loss: 0.2756 - val_accuracy: 0.9226
# Epoch 16/50
# 469/469 - 2s - loss: 0.2763 - accuracy: 0.9227 - val_loss: 0.2725 - val_accuracy: 0.9240
# Epoch 17/50
# 469/469 - 2s - loss: 0.2743 - accuracy: 0.9229 - val_loss: 0.2718 - val_accuracy: 0.9243
# Epoch 18/50
# 469/469 - 2s - loss: 0.2730 - accuracy: 0.9238 - val_loss: 0.2682 - val_accuracy: 0.9256
# Epoch 19/50
# 469/469 - 2s - loss: 0.2716 - accuracy: 0.9240 - val_loss: 0.2666 - val_accuracy: 0.9261
# Epoch 20/50
# 469/469 - 2s - loss: 0.2703 - accuracy: 0.9248 - val_loss: 0.2661 - val_accuracy: 0.9259
# Epoch 21/50
# 469/469 - 2s - loss: 0.2689 - accuracy: 0.9252 - val_loss: 0.2650 - val_accuracy: 0.9268
# Epoch 22/50
# 469/469 - 2s - loss: 0.2675 - accuracy: 0.9257 - val_loss: 0.2656 - val_accuracy: 0.9259
# Epoch 23/50
# 469/469 - 2s - loss: 0.2665 - accuracy: 0.9264 - val_loss: 0.2645 - val_accuracy: 0.9262
# Epoch 24/50
# 469/469 - 2s - loss: 0.2656 - accuracy: 0.9265 - val_loss: 0.2632 - val_accuracy: 0.9270
# Epoch 25/50
# 469/469 - 2s - loss: 0.2645 - accuracy: 0.9264 - val_loss: 0.2625 - val_accuracy: 0.9265
# Epoch 26/50
# 469/469 - 2s - loss: 0.2634 - accuracy: 0.9268 - val_loss: 0.2608 - val_accuracy: 0.9278
# Epoch 27/50
# 469/469 - 2s - loss: 0.2628 - accuracy: 0.9273 - val_loss: 0.2586 - val_accuracy: 0.9288
# Epoch 28/50
# 469/469 - 2s - loss: 0.2622 - accuracy: 0.9277 - val_loss: 0.2584 - val_accuracy: 0.9289
# Epoch 29/50
# 469/469 - 2s - loss: 0.2612 - accuracy: 0.9274 - val_loss: 0.2580 - val_accuracy: 0.9291
# Epoch 30/50
# 469/469 - 2s - loss: 0.2603 - accuracy: 0.9280 - val_loss: 0.2570 - val_accuracy: 0.9291
# Epoch 31/50
# 469/469 - 2s - loss: 0.2598 - accuracy: 0.9280 - val_loss: 0.2558 - val_accuracy: 0.9291
# Epoch 32/50
# 469/469 - 2s - loss: 0.2593 - accuracy: 0.9282 - val_loss: 0.2563 - val_accuracy: 0.9293
# Epoch 33/50
# 469/469 - 2s - loss: 0.2586 - accuracy: 0.9285 - val_loss: 0.2541 - val_accuracy: 0.9302
# Epoch 34/50
# 469/469 - 2s - loss: 0.2578 - accuracy: 0.9291 - val_loss: 0.2541 - val_accuracy: 0.9295
# Epoch 35/50
# 469/469 - 2s - loss: 0.2575 - accuracy: 0.9293 - val_loss: 0.2527 - val_accuracy: 0.9302
# Epoch 36/50
# 469/469 - 2s - loss: 0.2566 - accuracy: 0.9293 - val_loss: 0.2550 - val_accuracy: 0.9301
# Epoch 37/50
# 469/469 - 2s - loss: 0.2564 - accuracy: 0.9288 - val_loss: 0.2546 - val_accuracy: 0.9294
# Epoch 38/50
# 469/469 - 2s - loss: 0.2558 - accuracy: 0.9296 - val_loss: 0.2532 - val_accuracy: 0.9306
# Epoch 39/50
# 469/469 - 2s - loss: 0.2552 - accuracy: 0.9296 - val_loss: 0.2554 - val_accuracy: 0.9293
# Epoch 40/50
# 469/469 - 2s - loss: 0.2546 - accuracy: 0.9291 - val_loss: 0.2521 - val_accuracy: 0.9319
# Epoch 41/50
# 469/469 - 2s - loss: 0.2542 - accuracy: 0.9299 - val_loss: 0.2505 - val_accuracy: 0.9312
# Epoch 42/50
# 469/469 - 2s - loss: 0.2536 - accuracy: 0.9298 - val_loss: 0.2509 - val_accuracy: 0.9316
# Epoch 43/50
# 469/469 - 2s - loss: 0.2534 - accuracy: 0.9302 - val_loss: 0.2494 - val_accuracy: 0.9312
# Epoch 44/50
# 469/469 - 2s - loss: 0.2528 - accuracy: 0.9308 - val_loss: 0.2513 - val_accuracy: 0.9304
# Epoch 45/50
# 469/469 - 2s - loss: 0.2524 - accuracy: 0.9300 - val_loss: 0.2475 - val_accuracy: 0.9320
# Epoch 46/50
# 469/469 - 2s - loss: 0.2518 - accuracy: 0.9302 - val_loss: 0.2519 - val_accuracy: 0.9304
# Epoch 47/50
# 469/469 - 2s - loss: 0.2515 - accuracy: 0.9306 - val_loss: 0.2467 - val_accuracy: 0.9324
# Epoch 48/50
# 469/469 - 2s - loss: 0.2513 - accuracy: 0.9309 - val_loss: 0.2476 - val_accuracy: 0.9319
# Epoch 49/50
# 469/469 - 2s - loss: 0.2510 - accuracy: 0.9310 - val_loss: 0.2486 - val_accuracy: 0.9322
# Epoch 50/50
# 469/469 - 2s - loss: 0.2508 - accuracy: 0.9307 - val_loss: 0.2473 - val_accuracy: 0.9322

# %% [markdown]
# ### HaGraD

# %%
keras.backend.clear_session()
hagrad_optimizer = Hagrad()
print(hagrad_optimizer.get_config())
model_hagrad = model_optimizer(hagrad_optimizer)
fit_hagrad = model_fit(model_hagrad)
# Out:
# {'name': 'hagrad', 'epsilon': 1.0, 'gamma': 10.0, 'delta': 0.09090909090909091, 'kinetic_energy_gradient': 'Relativistic kinetic energy sqrt( ||p||^2 + 1 )-1 with gradient p/sqrt( ||p||^2 + 1 )'}
# Epoch 1/50
# 469/469 - 3s - loss: 0.4206 - accuracy: 0.8770 - val_loss: 0.3112 - val_accuracy: 0.9104
# Epoch 2/50
# 469/469 - 3s - loss: 0.3166 - accuracy: 0.9099 - val_loss: 0.2908 - val_accuracy: 0.9182
# Epoch 3/50
# 469/469 - 3s - loss: 0.3026 - accuracy: 0.9132 - val_loss: 0.3020 - val_accuracy: 0.9128
# Epoch 4/50
# 469/469 - 3s - loss: 0.2957 - accuracy: 0.9154 - val_loss: 0.2948 - val_accuracy: 0.9138
# Epoch 5/50
# 469/469 - 2s - loss: 0.2895 - accuracy: 0.9183 - val_loss: 0.2716 - val_accuracy: 0.9241
# Epoch 6/50
# 469/469 - 2s - loss: 0.2856 - accuracy: 0.9191 - val_loss: 0.2765 - val_accuracy: 0.9226
# Epoch 7/50
# 469/469 - 3s - loss: 0.2832 - accuracy: 0.9205 - val_loss: 0.2713 - val_accuracy: 0.9237
# Epoch 8/50
# 469/469 - 3s - loss: 0.2792 - accuracy: 0.9215 - val_loss: 0.2720 - val_accuracy: 0.9232
# Epoch 9/50
# 469/469 - 2s - loss: 0.2776 - accuracy: 0.9218 - val_loss: 0.2774 - val_accuracy: 0.9202
# Epoch 10/50
# 469/469 - 3s - loss: 0.2761 - accuracy: 0.9218 - val_loss: 0.2900 - val_accuracy: 0.9186
# Epoch 11/50
# 469/469 - 3s - loss: 0.2743 - accuracy: 0.9230 - val_loss: 0.2581 - val_accuracy: 0.9284
# Epoch 12/50
# 469/469 - 3s - loss: 0.2721 - accuracy: 0.9232 - val_loss: 0.2625 - val_accuracy: 0.9280
# Epoch 13/50
# 469/469 - 3s - loss: 0.2718 - accuracy: 0.9246 - val_loss: 0.2725 - val_accuracy: 0.9229
# Epoch 14/50
# 469/469 - 3s - loss: 0.2696 - accuracy: 0.9252 - val_loss: 0.2590 - val_accuracy: 0.9286
# Epoch 15/50
# 469/469 - 3s - loss: 0.2683 - accuracy: 0.9246 - val_loss: 0.2580 - val_accuracy: 0.9275
# Epoch 16/50
# 469/469 - 3s - loss: 0.2675 - accuracy: 0.9251 - val_loss: 0.2704 - val_accuracy: 0.9233
# Epoch 17/50
# 469/469 - 3s - loss: 0.2663 - accuracy: 0.9254 - val_loss: 0.2691 - val_accuracy: 0.9244
# Epoch 18/50
# 469/469 - 3s - loss: 0.2659 - accuracy: 0.9260 - val_loss: 0.2684 - val_accuracy: 0.9219
# Epoch 19/50
# 469/469 - 3s - loss: 0.2649 - accuracy: 0.9256 - val_loss: 0.2717 - val_accuracy: 0.9212
# Epoch 20/50
# 469/469 - 3s - loss: 0.2637 - accuracy: 0.9263 - val_loss: 0.2580 - val_accuracy: 0.9278
# Epoch 21/50
# 469/469 - 3s - loss: 0.2638 - accuracy: 0.9250 - val_loss: 0.2638 - val_accuracy: 0.9238
# Epoch 22/50
# 469/469 - 3s - loss: 0.2626 - accuracy: 0.9260 - val_loss: 0.2717 - val_accuracy: 0.9223
# Epoch 23/50
# 469/469 - 3s - loss: 0.2622 - accuracy: 0.9262 - val_loss: 0.2550 - val_accuracy: 0.9286
# Epoch 24/50
# 469/469 - 2s - loss: 0.2618 - accuracy: 0.9267 - val_loss: 0.2617 - val_accuracy: 0.9261
# Epoch 25/50
# 469/469 - 3s - loss: 0.2603 - accuracy: 0.9277 - val_loss: 0.2481 - val_accuracy: 0.9306
# Epoch 26/50
# 469/469 - 3s - loss: 0.2610 - accuracy: 0.9272 - val_loss: 0.2560 - val_accuracy: 0.9271
# Epoch 27/50
# 469/469 - 2s - loss: 0.2584 - accuracy: 0.9280 - val_loss: 0.2501 - val_accuracy: 0.9301
# Epoch 28/50
# 469/469 - 2s - loss: 0.2590 - accuracy: 0.9272 - val_loss: 0.2478 - val_accuracy: 0.9323
# Epoch 29/50
# 469/469 - 2s - loss: 0.2587 - accuracy: 0.9279 - val_loss: 0.2467 - val_accuracy: 0.9302
# Epoch 30/50
# 469/469 - 3s - loss: 0.2581 - accuracy: 0.9279 - val_loss: 0.2557 - val_accuracy: 0.9267
# Epoch 31/50
# 469/469 - 3s - loss: 0.2569 - accuracy: 0.9280 - val_loss: 0.2541 - val_accuracy: 0.9291
# Epoch 32/50
# 469/469 - 3s - loss: 0.2566 - accuracy: 0.9285 - val_loss: 0.2534 - val_accuracy: 0.9278
# Epoch 33/50
# 469/469 - 3s - loss: 0.2569 - accuracy: 0.9285 - val_loss: 0.2460 - val_accuracy: 0.9307
# Epoch 34/50
# 469/469 - 2s - loss: 0.2562 - accuracy: 0.9285 - val_loss: 0.2431 - val_accuracy: 0.9325
# Epoch 35/50
# 469/469 - 2s - loss: 0.2564 - accuracy: 0.9276 - val_loss: 0.2459 - val_accuracy: 0.9319
# Epoch 36/50
# 469/469 - 3s - loss: 0.2558 - accuracy: 0.9277 - val_loss: 0.2481 - val_accuracy: 0.9320
# Epoch 37/50
# 469/469 - 2s - loss: 0.2554 - accuracy: 0.9298 - val_loss: 0.2546 - val_accuracy: 0.9306
# Epoch 38/50
# 469/469 - 3s - loss: 0.2558 - accuracy: 0.9291 - val_loss: 0.2525 - val_accuracy: 0.9284
# Epoch 39/50
# 469/469 - 3s - loss: 0.2543 - accuracy: 0.9284 - val_loss: 0.2506 - val_accuracy: 0.9302
# Epoch 40/50
# 469/469 - 2s - loss: 0.2542 - accuracy: 0.9289 - val_loss: 0.2421 - val_accuracy: 0.9333
# Epoch 41/50
# 469/469 - 3s - loss: 0.2537 - accuracy: 0.9290 - val_loss: 0.2545 - val_accuracy: 0.9289
# Epoch 42/50
# 469/469 - 2s - loss: 0.2536 - accuracy: 0.9291 - val_loss: 0.2497 - val_accuracy: 0.9280
# Epoch 43/50
# 469/469 - 2s - loss: 0.2528 - accuracy: 0.9295 - val_loss: 0.2405 - val_accuracy: 0.9324
# Epoch 44/50
# 469/469 - 3s - loss: 0.2535 - accuracy: 0.9289 - val_loss: 0.2436 - val_accuracy: 0.9330
# Epoch 45/50
# 469/469 - 3s - loss: 0.2523 - accuracy: 0.9284 - val_loss: 0.2470 - val_accuracy: 0.9312
# Epoch 46/50
# 469/469 - 3s - loss: 0.2533 - accuracy: 0.9290 - val_loss: 0.2494 - val_accuracy: 0.9294
# Epoch 47/50
# 469/469 - 2s - loss: 0.2516 - accuracy: 0.9299 - val_loss: 0.2421 - val_accuracy: 0.9331
# Epoch 48/50
# 469/469 - 3s - loss: 0.2515 - accuracy: 0.9300 - val_loss: 0.2532 - val_accuracy: 0.9302
# Epoch 49/50
# 469/469 - 3s - loss: 0.2521 - accuracy: 0.9292 - val_loss: 0.2476 - val_accuracy: 0.9306
# Epoch 50/50
# 469/469 - 2s - loss: 0.2518 - accuracy: 0.9304 - val_loss: 0.2457 - val_accuracy: 0.9320

# %% [markdown]
# ---

# %% [markdown]
# ## Visualizing
#
# Keras is evaluating the validation error at the end of each epoch. Therefore teh validation errors get shifted for the visualization:

# %%
epochs_arr = np.arange(epochs)
epochs_arr_val = epochs_arr + 0.5

# %%
fig, ax = plt.subplots(figsize=(16, 10))
ax.set_title("Comparison of HaGraD with commonly used Optimizers", fontsize=22)
ax.plot(epochs_arr,     fit_adam.history['loss'],       "r-",  label="Adam training") 
ax.plot(epochs_arr_val, fit_adam.history['val_loss'],   "r--", label="Adam validation") 
ax.plot(epochs_arr,     fit_sgd.history['loss'],        "g-",  label="SGD training") 
ax.plot(epochs_arr_val, fit_sgd.history['val_loss'],    "g--", label="SGD validation") 
ax.plot(epochs_arr,     fit_hagrad.history['loss'],     "k-",  label="HaGraD training") 
ax.plot(epochs_arr_val, fit_hagrad.history['val_loss'], "k--", label="HaGraD validation") 
ax.set_xlabel("Epochs")
ax.set_ylabel("Loss - CategoricalCrossentropy")
ax.set_ylim(bottom=0.23, top=0.4)
leg = ax.legend(frameon=True, fontsize=18)
plt.show()
plt.close()

# %% [markdown]
# ---
